# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role":"user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(model=model, max_tokens=1000, messages=messages)
    return message.content[0].text

# %%
messages = []
add_user_message(messages, "what is quantum computing")
print("0",messages)
answer = chat(messages)
add_assistant_message(messages, answer)
answer
# Out:
# 0 [{'role': 'user', 'content': 'what is quantum computing'}]
# 'Quantum computing is a revolutionary approach to computation that harnesses the principles of quantum mechanics to process information in fundamentally different ways than classical computers.\n\n## Key Concepts\n\n**Quantum Bits (Qubits)**\n- Unlike classical bits that are either 0 or 1, qubits can exist in "superposition" - simultaneously being both 0 and 1 until measured\n- This allows quantum computers to explore many possible solutions simultaneously\n\n**Quantum Entanglement**\n- Qubits can be "entangled," meaning their states become interconnected regardless of physical distance\n- Changes to one qubit instantly affect its entangled partner\n\n**Quantum Interference**\n- Quantum algorithms manipulate probability amplitudes so that wrong answers cancel out and correct answers are amplified\n\n## How It Differs from Classical Computing\n\n| Classical Computing | Quantum Computing |\n|-------------------|------------------|\n| Processes bits sequentially | Processes qubits in parallel |\n| Deterministic results | Probabilistic results |\n| Limited by binary logic | Leverages quantum superposition |\n\n## Potential Applications\n\n- **Cryptography**: Breaking current encryption and creating quantum-secure communications\n- **Drug Discovery**: Modeling molecular interactions\n- **Financial Modeling**: Optimizing portfolios and risk analysis\n- **Artificial Intelligence**: Accelerating machine learning algorithms\n- **Climate Modeling**: Simulating complex environmental systems\n\n## Current Challenges\n\n- Quantum decoherence (qubits losing their quantum properties)\n- High error rates requiring quantum error correction\n- Need for extremely cold operating temperatures\n- Limited number of stable qubits in current systems\n\nWhile still largely experimental, quantum computing represents one of the most promising frontiers in technology, potentially solving problems that would take classical computers thousands of years to complete.'

# %%
add_user_message(messages, "write another sentence")
answer = chat(messages)
answer

# %%
# Out:
# 'Quantum computing could eventually revolutionize fields like materials science by enabling researchers to simulate the quantum behavior of atoms and molecules with unprecedented accuracy, potentially leading to breakthroughs in developing new superconductors, batteries, and catalysts.'
